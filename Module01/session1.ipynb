# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("im a dumb computer - something else...")
# Out:
# im a dumb computer - something else...

# %%
name = "John"
print(name)
# Out:
# John

# %%
name = "Alex"
print(name)
print("Alex")
# Out:
# Alex
# Alex

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
pi = 5.0
print(type(pi))
# Out:
# <class 'float'>

# %%
flag = True
print(type(flag))
# Out:
# <class 'bool'>

# %%
age = 20

if age > 18:
  print("Adult")
else:
  print("Minor")
# Out:
# Adult

# %%
age = 18

if age > 18:
  print("Adult")
else:
  print("Minor")

if age >= 18:
  print("Adult")
else:
  print("Minor")
# Out:
# Minor
# Adult

# %%
age = 20

if age > 18:
  print("Adult")
else:
  print("Minor")

age = 10
# Out:
# Adult

# %%
age = 18
if age > 18:
  print("Adult")
else:
  print("Minor")

age = 10
if age > 18:
  print("Adult")
else:
  print("Minor")

age = 50
if age > 18:
  print("Adult")
else:
  print("Minor")

age = 25
if age > 18:
  print("Adult")
else:
  print("Minor")
# Out:
# Minor
# Minor
# Adult
# Adult
